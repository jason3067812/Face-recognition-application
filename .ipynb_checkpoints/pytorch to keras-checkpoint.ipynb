# %%
import cv2
import numpy as np
import torch
from torch import nn
from model import LinkNet34
import torchvision.transforms as transforms
from torch.autograd import Variable
from PIL import Image, ImageFilter
import time
import sys

# %%
model = LinkNet34()
model.load_state_dict(torch.load('linknet.pth',map_location='cpu'))
print(model)

# %%
input_np = np.random.uniform(0, 1, (1, 3, 256, 256))
input_var = Variable(torch.FloatTensor(input_np))

# %%
from pytorch2keras import pytorch_to_keras
# we should specify shape of the input tensor
k_model = pytorch_to_keras(model, input_var, [(3, 256, 256,)], verbose=True)

# %%
k_model.summary()

# %%
k_model.save(r"C:\Users\jason\face_toolbox_keras-master\linknet_keras.h5")

# %%
from tensorflow.python.keras.models import load_model

k = load_model(r'C:\Users\jason\face_toolbox_keras-master\linknet_keras.h5')
k.summary()
# Out:
# C:\Users\jason\anaconda3\envs\aa\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\jason\anaconda3\envs\aa\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\jason\anaconda3\envs\aa\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
